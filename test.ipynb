# %%
# Import necessary libraries
from mss import mss  # Screen capturing library
import pydirectinput  # Library for programmatically controlling the mouse and keyboard
import cv2  # OpenCV library for computer vision tasks
import numpy as np  # NumPy for numerical operations
import pytesseract  # Tesseract OCR library for text recognition
from matplotlib import pyplot as plt  # Matplotlib for plotting
import time  # Time module for adding delays
from gym import Env  # Gym library for defining RL environments
from gym.spaces import Box, Discrete  # Gym spaces for defining observation and action spaces
from gym import spaces
# Set the Tesseract OCR executable path
pytesseract.pytesseract.tesseract_cmd = 'C:\\Program Files\\Tesseract-OCR\\tesseract.exe'

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import mss
import pytesseract

def capture_screen():
    with mss.mss() as sct:
        # Capture the entire screen
        monitor = {"top": 0, "left": 0, "width": 1920, "height": 1080}
        screenshot = sct.grab(monitor)
        return screenshot

def extract_text(image):
    text = pytesseract.image_to_string(image)
    return text

def plot_image(image):
    plt.imshow(image)
    plt.axis('off')
    plt.show()

def main():
    # Capture screen
    screenshot = capture_screen()

    # Convert screenshot to PIL Image
    pil_image = Image.frombytes("RGB", screenshot.size, screenshot.rgb)

    # Extract text from the captured screen
    extracted_text = extract_text(pil_image)
    print("Extracted text:")
    print(extracted_text)

    # Plot the captured screen
    plot_image(pil_image)

if __name__ == "__main__":
    main()

# %%
import cv2
import numpy as np
import pytesseract
import mss
import matplotlib.pyplot as plt
from PIL import Image

# # Initialize screen capture object
# sct = mss()

# # Define coordinates of the region to capture
# monitor = {"top": 750, "left": 950, "width": 700, "height": 150}
# monitor = {"top": 800, "left": 170, "width": 320, "height": 200}

# Function to capture screen
def capture_screen():
    with mss.mss() as sct:
        # Capture the entire screen
        monitor = {"top": 750, "left": 950, "width": 700, "height": 150}
        screenshot = sct.grab(monitor)
        return screenshot

# Function to extract text from image using Tesseract
def extract_text_from_image(screenshot):
    # Convert screenshot to PIL Image
    pil_image = Image.frombytes("RGB", screenshot.size, screenshot.rgb)
    # Perform OCR using Tesseract
    text = pytesseract.image_to_string(pil_image)
    return text

# %%
# Main function
def main():
    while True:
        # Capture screen
        image = capture_screen()
        
        # Extract text from captured image
        text = extract_text_from_image(image)
        print("Extracted Text:", text)
        
        # Plot the captured screen using Matplotlib
        plt.imshow(image)
        plt.axis('off')  # Turn off axes
        plt.show()
        
        # Check for escape key to exit
        if cv2.waitKey(1) & 0xFF == 27:
            break

if __name__ == "__main__":
    main()
# Out:
# Extracted Text: went both man turn true been th:
# Extracted Text: went both man turn true been th:
# Extracted Text: went both man turn true been th:
# Extracted Text: went both man turn true been th:
# Extracted Text: went both man turn true been th:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 21
#      18             break
#      20 if __name__ == "__main__":
# ---> 21     main()
#
# Cell In[17], line 8, in main()
#       5 image = capture_screen()
#       7 # Extract text from captured image
# ----> 8 text = extract_text_from_image(image)
#       9 print("Extracted Text:", text)
#      11 # Plot the captured screen using Matplotlib
#
# Cell In[10], line 28, in extract_text_from_image(screenshot)
#      26 pil_image = Image.frombytes("RGB", screenshot.size, screenshot.rgb)
#      27 # Perform OCR using Tesseract
# ...

# %%
a = extract_text_from_image(capture_screen())
len(a)

# %%
import pytesseract
import mss
import pyautogui

# Function to capture screen
def capture_screen():
    with mss.mss() as sct:
        # Capture the entire screen
        monitor = {"top": 750, "left": 950, "width": 700, "height": 150}
        screenshot = sct.grab(monitor)
        return screenshot

# Function to extract text from image using Tesseract
def extract_text_from_image(screenshot):
    # Convert screenshot to PIL Image
    pil_image = Image.frombytes("RGB", screenshot.size, screenshot.rgb)
    # Perform OCR using Tesseract
    text = pytesseract.image_to_string(pil_image)
    return text

def list_to_string(lst):
    # Join the list elements using a space as separator
    return ' '.join(lst)

# Main function
def main():
    while True:
        # Capture screen
        image = capture_screen()
        
        # Extract text from captured image
        text = extract_text_from_image(image)
        # print("Extracted Text:", text)
        
        # Input the first word using pyautogui
        first_words = list_to_string(text.split()[0:4])  # Extract the first word
        # print("Text to be entered: ",first_words)  
        pyautogui.write(first_words)  # Input the first word
        pyautogui.press('space')  # Press space

        # second_word = text.split()[1]
        # pyautogui.write(second_word)  # Input the first word
        # pyautogui.press('space')

        # third_word = text.split()[2]
        # pyautogui.write(third_word)  # Input the first word
        # pyautogui.press('space')
        
        # Capture screen after pressing space
        # updated_image = capture_screen()
        
        # # Plot the updated captured screen using Matplotlib
        # plt.imshow(updated_image)
        # plt.axis('off')  # Turn off axes
        # plt.show()
        
        # Check for escape key to exit
        # if cv2.waitKey(1) & 0xFF == 27:
        #     break

# %%
import time

time.sleep(2)

if __name__ == "__main__":
    main()
